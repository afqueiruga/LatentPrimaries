# %%
from tensorflow.python.tools import inspect_checkpoint as chkp

# %%
chkp.print_tensors_in_checkpoint_file(
    "/Users/afq/Google Drive/networks/training_water_lg/Poly_pT_0.0_1,4/model.ckpt-1200",
    tensor_name='',
    all_tensors=True)
# Out:
# tensor_name:  beta1_power
# 0.0
# tensor_name:  beta2_power
# 0.30071726
# tensor_name:  csv_output_num
# 0
# tensor_name:  dec_W
# [[-1.67463681 -0.47732728 -1.14092127  0.55070765]
#  [ 2.22953175  0.56569922  0.43593293  0.11411688]
#  [-0.29600995  0.05760029 -0.07495515  0.05485202]
#  [ 5.10640772 -1.16703078  1.72349326 -0.23812315]
#  [-3.0052144   0.6877309  -1.01766901  0.13415399]
#  [ 0.89939962 -0.2022854   0.29493295 -0.0560389 ]
#  [ 4.04906625 -0.9141578   1.33843977 -0.23477626]
#  [-4.95637945  1.12978857 -1.6681235   0.23916222]
#  [ 2.09753467 -0.48351056  0.71754421 -0.08268248]
#  [ 0.26753856 -0.05402888  0.07345861 -0.040336  ]
#  [ 0.76973319 -0.15973629  0.22043973 -0.10037072]
#  [-2.1908314   0.50416447 -0.74872298  0.08722065]
#  [ 2.26573128 -0.51814161  0.76462231 -0.10589481]
#  [-0.50815192  0.11695464 -0.17439038  0.0181324 ]]
# tensor_name:  dec_W/Adam
# [[ 7.91832309e-05  7.69835198e-06  1.52670339e-05 -3.57424333e-06]
# ...
